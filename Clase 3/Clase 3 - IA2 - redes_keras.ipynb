# %% [markdown]
# # Red neuronal de 3 capas ocultas

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
np.random.seed(2018)

#Edad/horas de esutdio/ promedio previo.
train_data, test_data = np.random.random((100000, 3)), np.random.random((100, 3))

labels = np.random.randint(2, size=(100000, 1)) #resultados de los examenes pass/fail

model = Sequential()
model.add(Dense(5, input_dim=3, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(4, activation='relu'))

model.add(Dense(4, activation='relu'))
model.add(Dense(4, activation='relu'))

model.add(Dense(1, activation='sigmoid'))



model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(train_data, labels, epochs=10)
predictions = model.predict(test_data)
# Out:
# Epoch 1/10
# 3125/3125 [==============================] - 15s 4ms/step - loss: 0.6932 - accuracy: 0.5006
# Epoch 2/10
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.6932 - accuracy: 0.4982
# Epoch 3/10
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.6932 - accuracy: 0.4978
# Epoch 4/10
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.6932 - accuracy: 0.5008
# Epoch 5/10
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.6932 - accuracy: 0.4991
# Epoch 6/10
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.6932 - accuracy: 0.5002
# Epoch 7/10
# 3125/3125 [==============================] - 14s 4ms/step - loss: 0.6932 - accuracy: 0.4983
# Epoch 8/10
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.6932 - accuracy: 0.4993
# Epoch 9/10
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.6932 - accuracy: 0.4981
# Epoch 10/10
# 3125/3125 [==============================] - 13s 4ms/step - loss: 0.6932 - accuracy: 0.4996
# 4/4 [==============================] - 0s 4ms/step
